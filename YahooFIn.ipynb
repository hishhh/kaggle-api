# %% [markdown]
# <a href="https://colab.research.google.com/github/hishhh/kaggle-api/blob/master/YahooFIn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yahoo_fin

# %%
pip install requests-html
# Out:
# ...
#      |████████████████████████████████| 92kB 5.7MB/s
# ...
#      |████████████████████████████████| 71kB 5.7MB/s
# ...
#      |████████████████████████████████| 143kB 11.3MB/s
# ...
#      |████████████████████████████████| 81kB 8.5MB/s
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-cp36-none-any.whl size=13485 sha256=ca921279853d0693f977b6bdc7c2d16cc0b599728c92dc5d1a50424d8d1b25e0
#   Stored in directory: /root/.cache/pip/wheels/5e/63/09/d1dc15179f175357d3f5c00cbffbac37f9e8690d80545143ff
# ...
#   Created wheel for parse: filename=parse-1.18.0-cp36-none-any.whl size=24134 sha256=00ef901590353a3398ff0e7557197677ab9df17614acefae8239d79f5afb4664
#   Stored in directory: /root/.cache/pip/wheels/2a/53/09/869ca5781ede342254ffac09ca99461b008c3e5f8dd079b0c0
# Successfully built fake-useragent parse
# ERROR: requests 2.23.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 1.26.2 which is incompatible.
# ...

# %%
from yahoo_fin import options

# %%
nflx_dates = options.get_expiration_dates("nflx")

# %%
print(nflx_dates)
# Out:
# ['January 8, 2021', 'January 15, 2021', 'January 22, 2021', 'January 29, 2021', 'February 5, 2021', 'February 12, 2021', 'February 19, 2021', 'March 19, 2021', 'June 18, 2021', 'July 16, 2021', 'September 17, 2021', 'January 21, 2022', 'March 18, 2022', 'June 17, 2022', 'January 20, 2023']

# %%
chain = options.get_options_chain("nflx")

# %%
chain["calls"]
# Out:
#           Contract Name  ... Implied Volatility
# 0   NFLX210108C00260000  ...              0.00%
# 1   NFLX210108C00265000  ...              0.00%
# 2   NFLX210108C00295000  ...              0.00%
# 3   NFLX210108C00305000  ...              0.00%
# 4   NFLX210108C00310000  ...              0.00%
# ..                  ...  ...                ...
# 79  NFLX210108C00710000  ...             50.00%
# 80  NFLX210108C00720000  ...             50.00%
# 81  NFLX210108C00730000  ...             50.00%
# 82  NFLX210108C00740000  ...             50.00%
# 83  NFLX210108C00750000  ...             50.00%
#
# [84 rows x 11 columns]

# %%
chain["puts"]
# Out:
#           Contract Name  ... Implied Volatility
# 0   NFLX210108P00255000  ...             50.00%
# 1   NFLX210108P00290000  ...             50.00%
# 2   NFLX210108P00300000  ...            237.50%
# 3   NFLX210108P00320000  ...             50.00%
# 4   NFLX210108P00325000  ...             50.00%
# ..                  ...  ...                ...
# 77  NFLX210108P00595000  ...              0.00%
# 78  NFLX210108P00600000  ...              0.00%
# 79  NFLX210108P00640000  ...              0.00%
# 80  NFLX210108P00650000  ...              0.00%
# 81  NFLX210108P00700000  ...              0.00%
#
# [82 rows x 11 columns]
